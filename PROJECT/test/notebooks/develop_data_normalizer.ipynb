# %%
# %env MINIO_HOST=minio
# %env MINIO_PORT=9000
# %env AWS_SECRET_KEY=Z8lN07OWSzRqDjcqR8vTr5H9gsrFnSqEgV3z1gLD
# %env AWS_ACCESS_KEY=CAsXP1ZVRAQXyftGOAim
# Out:
# env: MINIO_HOST=minio
# env: MINIO_PORT=9000
# env: AWS_SECRET_KEY=Z8lN07OWSzRqDjcqR8vTr5H9gsrFnSqEgV3z1gLD
# env: AWS_ACCESS_KEY=CAsXP1ZVRAQXyftGOAim

# %%
# %pip install minio
# Out:
# Collecting minio
#   Using cached minio-7.2.15-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from minio) (2023.7.22)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.11/site-packages (from minio) (2.0.7)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.11/site-packages (from minio) (23.1.0)
# Collecting pycryptodome (from minio)
#   Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from minio) (4.8.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.11/site-packages (from argon2-cffi->minio) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->minio) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->minio) (2.21)
# Using cached minio-7.2.15-py3-none-any.whl (95 kB)
# Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 16.6 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pycryptodome, minio
# Successfully installed minio-7.2.15 pycryptodome-3.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from functools import reduce
from typing import List, Literal, Tuple

from minio import Minio
from minio.commonconfig import CopySource
from pyspark.sql import DataFrame, SparkSession
from pyspark.sql.functions import col, current_timestamp, lit

# %%
def process_bluesky(spark: SparkSession, input_topic_path: str) -> DataFrame:
    """
    Bluesky topic contains two tables: Posts and Likes, with the following
    schemas:

    Posts:
        uri: str
        text: str
        created_at: datetime
        author_did: str
        author_handle: str
        author_display_name: str
        like_count: int
        repost_count: int
        reply_count: int
        quote_count: int

    Likes:
        actor_did: str
        actor_handle: str
        actor_display_name: str
        created_at: datetime
        post_uri: str
    """
    df_posts = spark.read.format("delta").load(f"s3a://{input_topic_path}/posts")
    df_likes = spark.read.format("delta").load(f"s3a://{input_topic_path}/likes")
    # Select only the columns we need from the posts table
    df_posts = df_posts.select(
        col("uri"),
        col("text"),
        col("created_at"),
        col("author_did").alias("author_uri"),
        col("repost_count").alias("reposts"),
        col("reply_count").alias("replies"),
        col("quote_count").alias("quotes"),
    )

    # Add the null columns that we don't have in the bluesky data
    df_posts = df_posts.withColumn("title", lit(None).cast("string"))
    df_posts = df_posts.withColumn("description", lit(None).cast("string"))
    df_posts = df_posts.withColumn("video_attachments", lit(None).cast("array<string>"))
    df_posts = df_posts.withColumn("image_attachments", lit(None).cast("array<string>"))
    df_posts = df_posts.withColumn("audio_attachments", lit(None).cast("array<string>"))
    df_posts = df_posts.withColumn("views", lit(None).cast("int"))
    df_posts = df_posts.withColumn("shares", lit(None).cast("int"))
    df_posts = df_posts.withColumn("dislikes", lit(None).cast("int"))

    # Finally, re-count the likes from the likes table
    df_likes = df_likes.groupBy("post_uri").count().withColumnRenamed("count", "likes")
    # Join the likes table with the posts table
    df = df_posts.join(df_likes, df_posts.uri == df_likes.post_uri, "left")
    df = df.drop(df_likes.post_uri)

    # Add the source column
    df = df.withColumn("source", lit("bluesky"))

    return df

# %%
def process_twitter(spark: SparkSession, input_topic_path: str) -> DataFrame:
    """
    Twitter topic contains one single table: Posts, with the following schema:

    Posts:
        uri: str
        text: str
        created_at: datetime
        like_count: int
        reply_count: int
        repost_count: int
    """
    df = spark.read.format("delta").load(f"s3a://{input_topic_path}/posts")
    # Select only the columns we need from the posts table
    df = df.select(
        col("uri"),
        col("text"),
        col("created_at"),
        col("like_count").alias("likes"),
        col("reply_count").alias("replies"),
        col("repost_count").alias("reposts"),
    )

    # Add the null columns that we don't have in the twitter data
    df = df.withColumn("author_uri", lit(None).cast("string"))
    df = df.withColumn("title", lit(None).cast("string"))
    df = df.withColumn("description", lit(None).cast("string"))
    df = df.withColumn("video_attachments", lit(None).cast("array<string>"))
    df = df.withColumn("image_attachments", lit(None).cast("array<string>"))
    df = df.withColumn("audio_attachments", lit(None).cast("array<string>"))
    df = df.withColumn("views", lit(None).cast("int"))
    df = df.withColumn("shares", lit(None).cast("int"))
    df = df.withColumn("dislikes", lit(None).cast("int"))
    df = df.withColumn("quotes", lit(None).cast("int"))

    # Add the source column
    df = df.withColumn("source", lit("twitter"))

    return df

# %%
def process_youtube(
    spark: SparkSession,
    input_topic_path: str,
    output_path: str,
    minio_host: str,
    minio_port: str,
    minio_access_key: str,
    minio_secret_key: str,
) -> DataFrame:
    """
    Youtube topic contains two tables: Video Metadata, and Comments.
    And three BLOB stores: Videos, Thumbnails, and Audios.

    The schemas of the tables are as follows:

    Video Metadata:
        title: str
        description: str
        url: str
        videoId: str
        channel: str
        publishedAt: str
        tags: str
        thumbnail: str (The url)
        viewCount: Optional[int]
        likeCount: Optional[int]
        commentCount: Optional[int]
        duration: Optional[str]
        definition: Optional[str]
        captions: Optional[str]

    Comments: (We will ignore this table for now, as YT API does only return a few top level comments)
        channelName: str
        channelId: Optional[str]
        comment: str
        likes: int
        replies: int
        publishedAt: datetime
        videoId: str
        threadId: str
    """
    df = spark.read.format("delta").load(f"s3a://{input_topic_path}/video_metadata")
    # Select only the columns we need from the video metadata table
    df = df.select(
        col("videoId").alias("uri"),
        col("title"),
        col("description"),
        col("channel").alias("author_uri"),
        col("publishedAt").alias("created_at"),
        col("viewCount").alias("views"),
        col("likeCount").alias("likes"),
        col("commentCount").alias("replies"),
        col("captions").alias("text"),
    )

    minio = Minio(
        f"{minio_host}:{minio_port}",
        access_key=minio_access_key,
        secret_key=minio_secret_key,
        secure=False,
    )
    src_bucket, src_folder = input_topic_path.split("/", 1)
    dst_bucket, dst_folder = output_path.split("/", 1)

    for dst_subfolder, src_subfolder in [("videos", "videos"), ("thumbnails", "images"), ("audios", "audios")]:
        # Check if the folder exists in the input path
        src_subfolder = f"{src_folder}/{src_subfolder}"
        dst_subfolder = f"{dst_folder}/{dst_subfolder}/youtube"

        print(
            f"Copying data from bucket={src_bucket},folder={src_subfolder} to bucket={dst_bucket},folder={dst_subfolder}"
        )
        src_files = minio.list_objects(src_bucket, recursive=True, prefix=src_subfolder)
        for file in src_files:
            src_basename = os.path.basename(file.object_name)
            dst_file = os.path.join(dst_subfolder, src_basename)
            print(f"Server-copying file {src_bucket}/{file.object_name} to {dst_bucket}/{dst_file}")
            minio.copy_object(dst_bucket, dst_file, CopySource(src_bucket, file.object_name))

    df = df.withColumn(
        "video_attachments", lit([f"{output_path}/videos/youtube/{col('uri')}.mp4"]).cast("array<string>")
    )
    df = df.withColumn(
        "image_attachments", lit([f"{output_path}/images/youtube/{col('uri')}.jpg"]).cast("array<string>")
    )
    df = df.withColumn(
        "audio_attachments", lit([f"{output_path}/audios/youtube/{col('uri')}.mp3"]).cast("array<string>")
    )

    # Add the null columns that we don't have in the youtube data
    df = df.withColumn("shares", lit(None).cast("int"))
    df = df.withColumn("dislikes", lit(None).cast("int"))
    df = df.withColumn("reposts", lit(None).cast("int"))
    df = df.withColumn("quotes", lit(None).cast("int"))

    # Add the source column
    df = df.withColumn("source", lit("youtube"))
    return df

# %%
input_sources = [("bluesky", "trusted/bluesky-a1cb100f"), ("youtube", "trusted/youtube-a1cb100f"), ("bluesky", "trusted/bluesky-3c77f261"), ("youtube", "trusted/youtube-3c77f261")]
output_path = "exploitation/microsoft/edge_browser"
minio_host = os.environ["MINIO_HOST"]
minio_port = os.environ["MINIO_PORT"]
minio_access_key = os.environ["AWS_ACCESS_KEY"]
minio_secret_key = os.environ["AWS_SECRET_KEY"]

# %%
spark = SparkSession.builder \
    .appName("DataNormalizer") \
    .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:3.3.1,io.delta:delta-spark_2.12:3.2.0") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .config("spark.executorEnv.AWS_ACCESS_KEY", os.environ["AWS_ACCESS_KEY"]) \
    .config("spark.executorEnv.AWS_SECRET_KEY", os.environ["AWS_SECRET_KEY"]) \
    .config("spark.hadoop.fs.s3a.endpoint", f"http://{os.environ['MINIO_HOST']}:{os.environ['MINIO_PORT']}") \
    .config("spark.hadoop.fs.s3a.path.style.access", "true") \
    .master("spark://spark-master:7077") \
    .getOrCreate()

# %%
source_dataframes: List[DataFrame] = []
for source, input_topic_path in input_sources:
    if source == "bluesky":
        res = process_bluesky(spark, input_topic_path)
    elif source == "youtube":
        res = process_youtube(
            spark, input_topic_path, output_path, minio_host, minio_port, minio_access_key, minio_secret_key
        )
    elif source == "twitter":
        res = process_twitter(spark, input_topic_path)
    else:
        raise ValueError(f"Unknown source: {source}")

    source_dataframes.append(res)
# Combine all dataframes into one
combined_df = reduce(lambda df1, df2: df1.unionByName(df2), source_dataframes)

# De-duplicate any posts that were captured twice by different queries, based
# on a combination of the uri and the source
combined_df = combined_df.dropDuplicates(["uri", "source"])

# Add the extraction id column
combined_df = combined_df.withColumn("extraction_id", lit(current_timestamp()))
# Out:
# Copying data from bucket=trusted,folder=youtube-a1cb100f/videos to bucket=trusted,folder=microsoft/edge_browser/videos/youtube
# Server-copying file trusted/youtube-a1cb100f/videos/-3J9J6iopDk.mp4 to trusted/microsoft/edge_browser/videos/youtube/-3J9J6iopDk.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/1kAAMawGxOQ.mp4 to trusted/microsoft/edge_browser/videos/youtube/1kAAMawGxOQ.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/27tr-dNQrxE.mp4 to trusted/microsoft/edge_browser/videos/youtube/27tr-dNQrxE.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/3o7pgfelr7I.mp4 to trusted/microsoft/edge_browser/videos/youtube/3o7pgfelr7I.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/7n3BZlASNKc.mp4 to trusted/microsoft/edge_browser/videos/youtube/7n3BZlASNKc.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/AUjfqGGqUBc.mp4 to trusted/microsoft/edge_browser/videos/youtube/AUjfqGGqUBc.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/DnxLtlho11s.mp4 to trusted/microsoft/edge_browser/videos/youtube/DnxLtlho11s.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/Ff9WUqV1sIc.mp4 to trusted/microsoft/edge_browser/videos/youtube/Ff9WUqV1sIc.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/G2eyrYwQDss.mp4 to trusted/microsoft/edge_browser/videos/youtube/G2eyrYwQDss.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/G8e_nDaq6_w.mp4 to trusted/microsoft/edge_browser/videos/youtube/G8e_nDaq6_w.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/L7_mKtGKDE8.mp4 to trusted/microsoft/edge_browser/videos/youtube/L7_mKtGKDE8.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/Mq71CVrbKq4.mp4 to trusted/microsoft/edge_browser/videos/youtube/Mq71CVrbKq4.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/QWnh72kJ5NQ.mp4 to trusted/microsoft/edge_browser/videos/youtube/QWnh72kJ5NQ.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/RzEg4yFOS7Y.mp4 to trusted/microsoft/edge_browser/videos/youtube/RzEg4yFOS7Y.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/S2t93lmQjfk.mp4 to trusted/microsoft/edge_browser/videos/youtube/S2t93lmQjfk.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/V5XPwH7m9X0.mp4 to trusted/microsoft/edge_browser/videos/youtube/V5XPwH7m9X0.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/VWQiNQC5j38.mp4 to trusted/microsoft/edge_browser/videos/youtube/VWQiNQC5j38.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/WdymIUeDvVw.mp4 to trusted/microsoft/edge_browser/videos/youtube/WdymIUeDvVw.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/WqN-oJ6F8cA.mp4 to trusted/microsoft/edge_browser/videos/youtube/WqN-oJ6F8cA.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/XKZjHGfa4Qk.mp4 to trusted/microsoft/edge_browser/videos/youtube/XKZjHGfa4Qk.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/Y14cuxKwQEE.mp4 to trusted/microsoft/edge_browser/videos/youtube/Y14cuxKwQEE.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/Y4hbyUWqthY.mp4 to trusted/microsoft/edge_browser/videos/youtube/Y4hbyUWqthY.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/b1PUqg9uoAU.mp4 to trusted/microsoft/edge_browser/videos/youtube/b1PUqg9uoAU.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/dStk20koCBY.mp4 to trusted/microsoft/edge_browser/videos/youtube/dStk20koCBY.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/fL3kjuysG9o.mp4 to trusted/microsoft/edge_browser/videos/youtube/fL3kjuysG9o.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/fY7XHgTgeF8.mp4 to trusted/microsoft/edge_browser/videos/youtube/fY7XHgTgeF8.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/hrDmr096tns.mp4 to trusted/microsoft/edge_browser/videos/youtube/hrDmr096tns.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/k2KPDRsNGe8.mp4 to trusted/microsoft/edge_browser/videos/youtube/k2KPDRsNGe8.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/mryD5BZkzYk.mp4 to trusted/microsoft/edge_browser/videos/youtube/mryD5BZkzYk.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/skO3ZlpOjGA.mp4 to trusted/microsoft/edge_browser/videos/youtube/skO3ZlpOjGA.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/tH8OWOU3dfY.mp4 to trusted/microsoft/edge_browser/videos/youtube/tH8OWOU3dfY.mp4
# Server-copying file trusted/youtube-a1cb100f/videos/uS6UIfWwnBo.mp4 to trusted/microsoft/edge_browser/videos/youtube/uS6UIfWwnBo.mp4
# Copying data from bucket=trusted,folder=youtube-a1cb100f/images to bucket=trusted,folder=microsoft/edge_browser/thumbnails/youtube
# Copying data from bucket=trusted,folder=youtube-a1cb100f/audios to bucket=trusted,folder=microsoft/edge_browser/audios/youtube
# Server-copying file trusted/youtube-a1cb100f/audios/-3J9J6iopDk.mp3 to trusted/microsoft/edge_browser/audios/youtube/-3J9J6iopDk.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/1kAAMawGxOQ.mp3 to trusted/microsoft/edge_browser/audios/youtube/1kAAMawGxOQ.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/27tr-dNQrxE.mp3 to trusted/microsoft/edge_browser/audios/youtube/27tr-dNQrxE.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/3o7pgfelr7I.mp3 to trusted/microsoft/edge_browser/audios/youtube/3o7pgfelr7I.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/7n3BZlASNKc.mp3 to trusted/microsoft/edge_browser/audios/youtube/7n3BZlASNKc.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/AUjfqGGqUBc.mp3 to trusted/microsoft/edge_browser/audios/youtube/AUjfqGGqUBc.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/DnxLtlho11s.mp3 to trusted/microsoft/edge_browser/audios/youtube/DnxLtlho11s.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/Ff9WUqV1sIc.mp3 to trusted/microsoft/edge_browser/audios/youtube/Ff9WUqV1sIc.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/G2eyrYwQDss.mp3 to trusted/microsoft/edge_browser/audios/youtube/G2eyrYwQDss.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/G8e_nDaq6_w.mp3 to trusted/microsoft/edge_browser/audios/youtube/G8e_nDaq6_w.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/L7_mKtGKDE8.mp3 to trusted/microsoft/edge_browser/audios/youtube/L7_mKtGKDE8.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/Mq71CVrbKq4.mp3 to trusted/microsoft/edge_browser/audios/youtube/Mq71CVrbKq4.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/QWnh72kJ5NQ.mp3 to trusted/microsoft/edge_browser/audios/youtube/QWnh72kJ5NQ.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/RzEg4yFOS7Y.mp3 to trusted/microsoft/edge_browser/audios/youtube/RzEg4yFOS7Y.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/S2t93lmQjfk.mp3 to trusted/microsoft/edge_browser/audios/youtube/S2t93lmQjfk.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/V5XPwH7m9X0.mp3 to trusted/microsoft/edge_browser/audios/youtube/V5XPwH7m9X0.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/VWQiNQC5j38.mp3 to trusted/microsoft/edge_browser/audios/youtube/VWQiNQC5j38.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/WdymIUeDvVw.mp3 to trusted/microsoft/edge_browser/audios/youtube/WdymIUeDvVw.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/WqN-oJ6F8cA.mp3 to trusted/microsoft/edge_browser/audios/youtube/WqN-oJ6F8cA.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/XKZjHGfa4Qk.mp3 to trusted/microsoft/edge_browser/audios/youtube/XKZjHGfa4Qk.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/Y14cuxKwQEE.mp3 to trusted/microsoft/edge_browser/audios/youtube/Y14cuxKwQEE.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/Y4hbyUWqthY.mp3 to trusted/microsoft/edge_browser/audios/youtube/Y4hbyUWqthY.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/b1PUqg9uoAU.mp3 to trusted/microsoft/edge_browser/audios/youtube/b1PUqg9uoAU.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/dStk20koCBY.mp3 to trusted/microsoft/edge_browser/audios/youtube/dStk20koCBY.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/fL3kjuysG9o.mp3 to trusted/microsoft/edge_browser/audios/youtube/fL3kjuysG9o.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/fY7XHgTgeF8.mp3 to trusted/microsoft/edge_browser/audios/youtube/fY7XHgTgeF8.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/hrDmr096tns.mp3 to trusted/microsoft/edge_browser/audios/youtube/hrDmr096tns.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/k2KPDRsNGe8.mp3 to trusted/microsoft/edge_browser/audios/youtube/k2KPDRsNGe8.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/mryD5BZkzYk.mp3 to trusted/microsoft/edge_browser/audios/youtube/mryD5BZkzYk.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/skO3ZlpOjGA.mp3 to trusted/microsoft/edge_browser/audios/youtube/skO3ZlpOjGA.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/tH8OWOU3dfY.mp3 to trusted/microsoft/edge_browser/audios/youtube/tH8OWOU3dfY.mp3
# Server-copying file trusted/youtube-a1cb100f/audios/uS6UIfWwnBo.mp3 to trusted/microsoft/edge_browser/audios/youtube/uS6UIfWwnBo.mp3
# Copying data from bucket=trusted,folder=youtube-3c77f261/videos to bucket=trusted,folder=microsoft/edge_browser/videos/youtube
# Server-copying file trusted/youtube-3c77f261/videos/_Fqx1jtdwBQ.mp4 to trusted/microsoft/edge_browser/videos/youtube/_Fqx1jtdwBQ.mp4
# Server-copying file trusted/youtube-3c77f261/videos/uSg0_CfBTVA.mp4 to trusted/microsoft/edge_browser/videos/youtube/uSg0_CfBTVA.mp4
# Server-copying file trusted/youtube-3c77f261/videos/wXtVRaggbVk.mp4 to trusted/microsoft/edge_browser/videos/youtube/wXtVRaggbVk.mp4
# Copying data from bucket=trusted,folder=youtube-3c77f261/images to bucket=trusted,folder=microsoft/edge_browser/thumbnails/youtube
# Copying data from bucket=trusted,folder=youtube-3c77f261/audios to bucket=trusted,folder=microsoft/edge_browser/audios/youtube
# Server-copying file trusted/youtube-3c77f261/audios/_Fqx1jtdwBQ.mp3 to trusted/microsoft/edge_browser/audios/youtube/_Fqx1jtdwBQ.mp3
# Server-copying file trusted/youtube-3c77f261/audios/uSg0_CfBTVA.mp3 to trusted/microsoft/edge_browser/audios/youtube/uSg0_CfBTVA.mp3
# Server-copying file trusted/youtube-3c77f261/audios/wXtVRaggbVk.mp3 to trusted/microsoft/edge_browser/audios/youtube/wXtVRaggbVk.mp3

# %%
combined_df.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+-------+-------+------+--------------------+--------------------+--------------------+--------------------+--------------------+-----+------+--------+-----+-------+--------------------+
# |                 uri|                text|          created_at|          author_uri|reposts|replies|quotes|               title|         description|   video_attachments|   image_attachments|   audio_attachments|views|shares|dislikes|likes| source|       extraction_id|
# +--------------------+--------------------+--------------------+--------------------+-------+-------+------+--------------------+--------------------+--------------------+--------------------+--------------------+-----+------+--------+-----+-------+--------------------+
# |         1kAAMawGxOQ|                NULL| 2025-05-17 12:58:31|            TeddyKho|   NULL|    253|  NULL|HP MIDRANGE PAKET...|Motorola Edge 60 ...|[trusted/microsof...|[trusted/microsof...|[trusted/microsof...| 8316|  NULL|    NULL|  278|youtube|2025-05-18 15:35:...|
# |         G2eyrYwQDss|                NULL| 2025-05-17 15:37:48|           Altaf trt|   NULL|      2|  NULL|Seth Rollins Save...|Seth Rollins Save...|[trusted/microsof...|[trusted/microsof...|[trusted/microsof...|17321|  NULL|    NULL|  294|youtube|2025-05-18 15:35:...|
# |         G8e_nDaq6_w|                NULL| 2025-05-17 12:55:13|          Tech Guide|   NULL|      0|  NULL|Moto Edge 60 Styl...|This shot is abou...|[trusted/microsof...|[trusted/microsof...|[trusted/microsof...| 4213|  NULL|    NULL|  100|youtube|2025-05-18 15:35:...|
# |         QWnh72kJ5NQ|                NULL| 2025-05-17 23:40:59|          THIAGOCARD|   NULL|      0|  NULL|Motorola Edge 60 ...|                    |[trusted/microsof...|[trusted/microsof...|[trusted/microsof...| 1044|  NULL|    NULL|    8|youtube|2025-05-18 15:35:...|
# |at://did:plc:226s...|          BING BONG!|2025-05-17 06:42:...|did:plc:226seyh44...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:35:...|
# |at://did:plc:22ls...|Nuggets edge clos...| 2025-05-15 18:13:33|did:plc:22lskm3yq...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:35:...|
# |at://did:plc:22yy...|This piece is two...| 2025-05-01 00:02:28|did:plc:22yyehc52...|      1|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:35:...|
# |at://did:plc:235b...|1345 days! I doub...|2025-05-15 18:50:...|did:plc:235boeody...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:35:...|
# |at://did:plc:23j4...|Up next in Dad’s ...|2025-05-15 15:49:...|did:plc:23j42cy7g...|      2|      1|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL|   70|bluesky|2025-05-18 15:35:...|
# |at://did:plc:23pk...|theres some good ...|2025-05-14 21:41:...|did:plc:23pkb2in5...|      0|      1|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL|    1|bluesky|2025-05-18 15:35:...|
# |at://did:plc:23wj...|Make sure it’s in...|2025-05-16 23:08:...|did:plc:23wj2amjb...|      0|      1|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL|    2|bluesky|2025-05-18 15:35:...|
# |at://did:plc:244r...|I’ve kept Edge as...|2025-05-14 21:55:...|did:plc:244rlhn3z...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:35:...|
# |at://did:plc:24np...|On: @UtilizingTec...|2025-05-14 16:32:...|did:plc:24np2l3xo...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:35:...|
# |at://did:plc:254f...|Playing on Edge 1...| 2025-05-14 13:38:10|did:plc:254fa7kdh...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:35:...|
# |at://did:plc:254f...|Playing on Edge 1...| 2025-05-14 13:46:08|did:plc:254fa7kdh...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:35:...|
# |at://did:plc:254f...|Playing on Edge 1...| 2025-05-14 14:06:09|did:plc:254fa7kdh...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:35:...|
# |at://did:plc:254f...|Playing on Edge 1...| 2025-05-14 14:22:08|did:plc:254fa7kdh...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:35:...|
# |at://did:plc:254f...|Playing on Edge 1...| 2025-05-14 14:38:11|did:plc:254fa7kdh...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:35:...|
# |at://did:plc:254f...|Playing on Edge 1...| 2025-05-14 14:40:07|did:plc:254fa7kdh...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:35:...|
# |at://did:plc:254f...|Playing on Edge 1...| 2025-05-14 14:56:11|did:plc:254fa7kdh...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:35:...|
# +--------------------+--------------------+--------------------+--------------------+-------+-------+------+--------------------+--------------------+--------------------+--------------------+--------------------+-----+------+--------+-----+-------+--------------------+
# only showing top 20 rows

# %%
# Write the DataFrame to the output path in Delta format
combined_df.write.format("delta").mode("append").save(f"s3a://{output_path}/data")

# %%
df = spark.read.format("delta").load(f"s3a://{output_path}")

# %%
df.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+-------+-------+------+--------------------+--------------------+--------------------+--------------------+--------------------+-----+------+--------+-----+-------+--------------------+
# |                 uri|                text|          created_at|          author_uri|reposts|replies|quotes|               title|         description|   video_attachments|   image_attachments|   audio_attachments|views|shares|dislikes|likes| source|       extraction_id|
# +--------------------+--------------------+--------------------+--------------------+-------+-------+------+--------------------+--------------------+--------------------+--------------------+--------------------+-----+------+--------+-----+-------+--------------------+
# |         1kAAMawGxOQ|                NULL| 2025-05-17 12:58:31|            TeddyKho|   NULL|    253|  NULL|HP MIDRANGE PAKET...|Motorola Edge 60 ...|[trusted/microsof...|[trusted/microsof...|[trusted/microsof...| 8316|  NULL|    NULL|  278|youtube|2025-05-18 15:36:...|
# |         G2eyrYwQDss|                NULL| 2025-05-17 15:37:48|           Altaf trt|   NULL|      2|  NULL|Seth Rollins Save...|Seth Rollins Save...|[trusted/microsof...|[trusted/microsof...|[trusted/microsof...|17321|  NULL|    NULL|  294|youtube|2025-05-18 15:36:...|
# |         G8e_nDaq6_w|                NULL| 2025-05-17 12:55:13|          Tech Guide|   NULL|      0|  NULL|Moto Edge 60 Styl...|This shot is abou...|[trusted/microsof...|[trusted/microsof...|[trusted/microsof...| 4213|  NULL|    NULL|  100|youtube|2025-05-18 15:36:...|
# |         QWnh72kJ5NQ|                NULL| 2025-05-17 23:40:59|          THIAGOCARD|   NULL|      0|  NULL|Motorola Edge 60 ...|                    |[trusted/microsof...|[trusted/microsof...|[trusted/microsof...| 1044|  NULL|    NULL|    8|youtube|2025-05-18 15:36:...|
# |at://did:plc:226s...|          BING BONG!|2025-05-17 06:42:...|did:plc:226seyh44...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:36:...|
# |at://did:plc:22ls...|Nuggets edge clos...| 2025-05-15 18:13:33|did:plc:22lskm3yq...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:36:...|
# |at://did:plc:22yy...|This piece is two...| 2025-05-01 00:02:28|did:plc:22yyehc52...|      1|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:36:...|
# |at://did:plc:235b...|1345 days! I doub...|2025-05-15 18:50:...|did:plc:235boeody...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:36:...|
# |at://did:plc:23j4...|Up next in Dad’s ...|2025-05-15 15:49:...|did:plc:23j42cy7g...|      2|      1|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL|   70|bluesky|2025-05-18 15:36:...|
# |at://did:plc:23pk...|theres some good ...|2025-05-14 21:41:...|did:plc:23pkb2in5...|      0|      1|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL|    1|bluesky|2025-05-18 15:36:...|
# |at://did:plc:23wj...|Make sure it’s in...|2025-05-16 23:08:...|did:plc:23wj2amjb...|      0|      1|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL|    2|bluesky|2025-05-18 15:36:...|
# |at://did:plc:244r...|I’ve kept Edge as...|2025-05-14 21:55:...|did:plc:244rlhn3z...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:36:...|
# |at://did:plc:24np...|On: @UtilizingTec...|2025-05-14 16:32:...|did:plc:24np2l3xo...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:36:...|
# |at://did:plc:254f...|Playing on Edge 1...| 2025-05-14 13:38:10|did:plc:254fa7kdh...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:36:...|
# |at://did:plc:254f...|Playing on Edge 1...| 2025-05-14 13:46:08|did:plc:254fa7kdh...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:36:...|
# |at://did:plc:254f...|Playing on Edge 1...| 2025-05-14 14:06:09|did:plc:254fa7kdh...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:36:...|
# |at://did:plc:254f...|Playing on Edge 1...| 2025-05-14 14:22:08|did:plc:254fa7kdh...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:36:...|
# |at://did:plc:254f...|Playing on Edge 1...| 2025-05-14 14:38:11|did:plc:254fa7kdh...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:36:...|
# |at://did:plc:254f...|Playing on Edge 1...| 2025-05-14 14:40:07|did:plc:254fa7kdh...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:36:...|
# |at://did:plc:254f...|Playing on Edge 1...| 2025-05-14 14:56:11|did:plc:254fa7kdh...|      0|      0|     0|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|  NULL|    NULL| NULL|bluesky|2025-05-18 15:36:...|
# +--------------------+--------------------+--------------------+--------------------+-------+-------+------+--------------------+--------------------+--------------------+--------------------+--------------------+-----+------+--------+-----+-------+--------------------+
# only showing top 20 rows
